# %% [markdown]
# ### Import Modules

# %%
import pandas as pd

# %% [markdown]
# ### Reading CSV file
#
# Source of the file : https://www.kaggle.com/datasets/ratikkakkar/electric-vehicle-population-data
#
# Repository : FODS-Assignments
#
# Repo link  : https://github.com/berinta/FODS-Assignments
#
# Dataset File path : FODS-Assignments/Assignment 1/Dataset/Electric_Vehicle_Population_Data.csv

# %%
electric_df = pd.read_csv('https://raw.githubusercontent.com/berinta/FODS-Assignments/main/Assignment%201/Dataset/Electric_Vehicle_Population_Data.csv')

# %% [markdown]
# ### Displaying top 5 rows

# %%
electric_df.head()
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year   Make  \
# 0  WAUTPBFF4H      King  Seattle    WA      98126.0        2017   AUDI
# 1  WAUUPBFF2J  Thurston  Olympia    WA      98502.0        2018   AUDI
# 2  5YJSA1E22H  Thurston    Lacey    WA      98516.0        2017  TESLA
# 3  1C4JJXP62M  Thurston   Tenino    WA      98589.0        2021   JEEP
# 4  5YJ3E1EC9L    Yakima   Yakima    WA      98902.0        2020  TESLA
#
#       Model                   Electric Vehicle Type  \
# 0        A3  Plug-in Hybrid Electric Vehicle (PHEV)
# 1        A3  Plug-in Hybrid Electric Vehicle (PHEV)
# 2   MODEL S          Battery Electric Vehicle (BEV)
# 3  WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)
# 4   MODEL 3          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0             Not eligible due to low battery range              16
# 1             Not eligible due to low battery range              16
# ...

# %% [markdown]
# ### Columns

# %%
list(electric_df.columns.values)
# Out:
# ['VIN (1-10)',
#  'County',
#  'City',
#  'State',
#  'Postal Code',
#  'Model Year',
#  'Make',
#  'Model',
#  'Electric Vehicle Type',
#  'Clean Alternative Fuel Vehicle (CAFV) Eligibility',
#  'Electric Range',
#  'Base MSRP',
#  'Legislative District',
#  'DOL Vehicle ID',
#  'Vehicle Location',
#  'Electric Utility',
#  '2020 Census Tract']

# %% [markdown]
# ### Column Data Types

# %%
electric_df.dtypes
# Out:
# VIN (1-10)                                            object
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                         int64
# Base MSRP                                              int64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                      object
# ...

# %% [markdown]
# ### 5 point Summary (Count, Mean, Standard Deviation, Min, Max, percentiles)

# %%
electric_df.describe()
# Out:
#         Postal Code    Model Year  Electric Range      Base MSRP  \
# count  88684.000000  88685.000000    88685.000000   88685.000000
# mean   98188.881557   2020.641833       58.129898    1053.400237
# std      517.613149      2.952576       91.496771    8532.183675
# min    20003.000000   1998.000000        0.000000       0.000000
# 25%    98040.000000   2019.000000        0.000000       0.000000
# 50%    98110.000000   2022.000000        0.000000       0.000000
# 75%    98199.000000   2023.000000       75.000000       0.000000
# max    99403.000000   2024.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count          88674.000000    8.868500e+04       8.868400e+04
# mean              31.679207    2.215577e+08       5.303099e+10
# std               14.357208    7.581123e+07       4.066455e+08
# min                1.000000    4.385000e+03       6.029005e+09
# 25%               20.000000    1.831826e+08       5.303301e+10
# ...

# %% [markdown]
# ### Insights & Actions
#
# **Trend Analysis:** By analyzing the model year, make, and model, one can identify trends in electric vehicle adoption over time, highlighting which manufacturers and models are gaining popularity.
#
# **Geographic Distribution:** Understanding the distribution of vehicles across different counties and cities can inform infrastructure investments, such as where to build new charging stations.
